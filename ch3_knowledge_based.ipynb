# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Simple Recommender

# %%
df = pd.read_csv("movies_metadata.csv")
# Out:
# /home/crimson/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# choosing m (minimum votes required to qualify) as 80th percentile movie
m = df['vote_count'].quantile(0.80)
m
# Out:
# 50.0

# %%
# only movies with m votes or more
q_movies = df[df['vote_count'] > 45]

# %%
# Only movies with specific runtime threshold
q_movies = q_movies[(q_movies['runtime'] > 45) & (q_movies['runtime'] < 300)]

# %%
q_movies.shape, df.shape
# Out:
# ((9420, 24), (45466, 24))

# %%
# calculate C: average rating of all movies, to capture how strict the community is.
C = df['vote_average'].mean()
C
# Out:
# 5.618207215133889

# %%
# rating metric function
def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    return (v/(v+m) * R + m/(v+m) * C)

# %%
q_movies['score'] = q_movies.apply(weighted_rating, axis=1)

# %%
q_movies.sort_values('score', ascending=False).head()
# Out:
#        adult                              belongs_to_collection     budget  \
# 10309  False                                                NaN   13200000
# 314    False                                                NaN   25000000
# 834    False  {'id': 230, 'name': 'The Godfather Collection'...    6000000
# 40251  False                                                NaN          0
# 12481  False  {'id': 263, 'name': 'The Dark Knight Collectio...  185000000
#
#                                                   genres  \
# 10309  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 314    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 834    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 40251  [{'id': 10749, 'name': 'Romance'}, {'id': 16, ...
# 12481  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
#
#                                               homepage      id    imdb_id  \
# 10309                                              NaN   19404  tt0112870
# ...

# %% [markdown]
# ## Knowledge-based Recommender

# %% [markdown]
# ### Take inputs from user: genres, runtime, release timeline and then recommend

# %% [markdown]
# ##### Cleaning release year:

# %%
df = pd.read_csv("movies_metadata.csv")
#Only keep those features that we require 
df = df[['title','genres', 'release_date', 'runtime', 'vote_average', 'vote_count']]
# Out:
# /home/crimson/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                               genres release_date  runtime  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...   1995-10-30     81.0
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   1995-12-15    104.0
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   1995-12-22    101.0
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   1995-12-22    127.0
# 4                     [{'id': 35, 'name': 'Comedy'}]   1995-02-10    106.0
#
#    vote_average  vote_count
# 0           7.7      5415.0
# 1           6.9      2413.0
# 2           6.5        92.0
# 3           6.1        34.0
# 4           5.7       173.0

# %%
# convert release date to pandas datetime format
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# extract year from datetime
df['year'] = df['release_date'].apply(lambda x: str(x).split('-')[0] if x != np.nan else np.nan)

# %%
# function to convert 'year' into integers and NaT to 0
def convert_int(x):
    try:
        return int(x)
    except:
        return 0
    
# Apply function to year
df['year'] = df['year'].apply(convert_int)

# %%
# remove 'release_date'
df = df.drop('release_date', axis=1)

# %%
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                               genres  runtime  vote_average  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     81.0           7.7
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    104.0           6.9
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...    101.0           6.5
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    127.0           6.1
# 4                     [{'id': 35, 'name': 'Comedy'}]    106.0           5.7
#
#    vote_count  year
# 0      5415.0  1995
# 1      2413.0  1995
# 2        92.0  1995
# 3        34.0  1995
# 4       173.0  1995

# %% [markdown]
# ##### Genre cleaning:

# %%
# how genre looks
df.iloc[0]['genres']
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %%
# convert stringed json to list (basically remove quotes)
from ast import literal_eval
df['genres'] = df['genres'].fillna('[]')
df['genres'] = df['genres'].apply(literal_eval)
df['genres'] = df['genres'].apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
df.head()
# Out:
#                          title                        genres  runtime  \
# 0                    Toy Story   [Animation, Comedy, Family]     81.0
# 1                      Jumanji  [Adventure, Fantasy, Family]    104.0
# 2             Grumpier Old Men             [Romance, Comedy]    101.0
# 3            Waiting to Exhale      [Comedy, Drama, Romance]    127.0
# 4  Father of the Bride Part II                      [Comedy]    106.0
#
#    vote_average  vote_count  year
# 0           7.7      5415.0  1995
# 1           6.9      2413.0  1995
# 2           6.5        92.0  1995
# 3           6.1        34.0  1995
# 4           5.7       173.0  1995

# %%
# explode genres in the list to multiple rows
exploded_genres = df.genres.apply(pd.Series).stack().reset_index(level=1, drop=True)
exploded_genres.name = 'genre'
exploded_movies = df.drop('genres', axis=1)
exploded_movies = exploded_movies.join(exploded_genres.to_frame())

# %%
exploded_movies.head()
# Out:
#        title  runtime  vote_average  vote_count  year      genre
# 0  Toy Story     81.0           7.7      5415.0  1995  Animation
# 0  Toy Story     81.0           7.7      5415.0  1995     Comedy
# 0  Toy Story     81.0           7.7      5415.0  1995     Family
# 1    Jumanji    104.0           6.9      2413.0  1995  Adventure
# 1    Jumanji    104.0           6.9      2413.0  1995    Fantasy

# %%
# Now apply the simple recommender taking inputs from user
# percentile for choosing 'm'
def build_chart(exploded_movies, percentile=0.8):
    #Ask for preferred genres
    print("Input preferred genre")
    genre = input()
    
    #Ask for lower limit of duration
    print("Input shortest duration")
    low_time = int(input())
    
    #Ask for upper limit of duration
    print("Input longest duration")
    high_time = int(input())
    
    #Ask for lower limit of timeline
    print("Input earliest year")
    low_year = int(input())
    
    #Ask for upper limit of timeline
    print("Input latest year")
    high_year = int(input())
    
    #Define a new movies variable to store the preferred movies. Copy the contents of gen_df to movies
    movies = exploded_movies.copy()
    
    #Filter based on the condition
    movies = movies[(movies['genre'] == genre) & 
                    (movies['runtime'] >= low_time) & 
                    (movies['runtime'] <= high_time) & 
                    (movies['year'] >= low_year) & 
                    (movies['year'] <= high_year)]
    
    #Compute the values of C and m for the filtered movies
    C = movies['vote_average'].mean()
    m = movies['vote_count'].quantile(percentile)
    
    #Only consider movies that have higher than m votes. Save this in a new dataframe q_movies
    q_movies = movies.copy().loc[movies['vote_count'] >= m]
    
    #Calculate score using the weighted rating formula
    q_movies['score'] = q_movies.apply(lambda x: (x['vote_count']/(x['vote_count']+m) * x['vote_average']) 
                                       + (m/(m+x['vote_count']) * C)
                                       ,axis=1)
    
    #Sort movies in descending order of their scores
    q_movies = q_movies.sort_values('score', ascending=False)
    
    return q_movies

# %%
# the recommendations
build_chart(exploded_movies).head()
# Out:
# Input preferred genre
# Animation
# Input shortest duration
# 60
# Input longest duration
# 200
# Input earliest year
# 2005
# Input latest year
# 2019
#             title  runtime  vote_average  vote_count  year      genre  \
# 40251  Your Name.    106.0           8.5      1030.0  2016  Animation
# 30315  Inside Out     94.0           7.9      6737.0  2015  Animation
# 13724          Up     96.0           7.8      7048.0  2009  Animation
# 12704      WALL·E     98.0           7.8      6439.0  2008  Animation
# 24455  Big Hero 6    102.0           7.8      6289.0  2014  Animation
#
#           score
# 40251  7.964102
# 30315  7.825001
# 13724  7.732708
# 12704  7.726659
# 24455  7.724998

# %%
exploded_movies.to_csv('metadata_clean.csv')
